# %%
import pandas as pd #widely used for data manipulation and analysis
import numpy as np #a fundamental library for numerical computations in Python
import matplotlib.pyplot as plt #Imports the pyplot module from Matplotlib, which is used for creating static, animated, and interactive plots
import seaborn as sns #library to design creative informative statistical and attractive graphics
# %matplotlib inline #allows plot to display directly in notebook
# Out:
# UsageError: unrecognized arguments: #allows plot to display directly in notebook

# %%
#to install pandas
#!pip install pandas

# %%
# to check panda is installed or not
#import pandas as pd
#print(pd.__version__)
# Out:
# 2.2.3

# %%
#to install matplotlib
#!pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/8.0 MB 2.9 MB/s eta 0:00:03
#    ------- -------------------------------- 1.6/8.0 MB 2.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.1/8.0 MB 2.6 MB/s eta 0:00:03
#    ------------- -------------------------- 2.6/8.0 MB 2.6 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.0 MB 2.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.0 MB 2.5 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.0 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/8.0 MB 2.4 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.0 MB 2.4 MB/s eta 0:00:02
#    --------------------------- ------------ 5.5/8.0 MB 2.4 MB/s eta 0:00:02
#    ------------------------------ --------- 6.0/8.0 MB 2.4 MB/s eta 0:00:01
# ...

# %%
#to install seaborn
#!pip install seaborn

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\Garima Rawat\OneDrive\Datasets\EDA-Zomato\zomato.csv",encoding='latin-1') #r before the file path ensures the string is treated as a raw string, avoiding issues with backslashes (\) in the path, latin-1 handle special characters in file
df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
# ...

# %%
df.columns #dtype=object is not referring to the value in the columns but to all the names of columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info() #give information about no. of null values in columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe() #provide 5 order summary of the numerical data
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.describe(include='object') #provide 5 order summary of object type of data
# Out:
#         Restaurant Name       City           Address         Locality  \
# count              9551       9551              9551             9551
# unique             7446        141              8918             1208
# top     Cafe Coffee Day  New Delhi  Sector 41, Noida  Connaught Place
# freq                 83       5473                11              122
#
#                   Locality Verbose      Cuisines            Currency  \
# count                         9551          9542                9551
# unique                        1265          1825                  12
# top     Connaught Place, New Delhi  North Indian  Indian Rupees(Rs.)
# freq                           122           936                8652
#
#        Has Table booking Has Online delivery Is delivering now  \
# count               9551                9551              9551
# unique                 2                   2                 2
# top                   No                  No                No
# ...

# %%
df.shape #gives no. of rows, columns
# Out:
# (9551, 21)

# %%
df.isnull().head() #gives true if any value is null, head gives first 5 rows
# Out:
#    Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0          False            False         False  False    False     False
# 1          False            False         False  False    False     False
# 2          False            False         False  False    False     False
# 3          False            False         False  False    False     False
# 4          False            False         False  False    False     False
#
#    Locality Verbose  Longitude  Latitude  Cuisines  ...  Currency  \
# 0             False      False     False     False  ...     False
# 1             False      False     False     False  ...     False
# 2             False      False     False     False  ...     False
# 3             False      False     False     False  ...     False
# 4             False      False     False     False  ...     False
#
#    Has Table booking  Has Online delivery  Is delivering now  \
# ...

# %%
df.isnull().sum() #gives sum of all null values in a column
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.isnull().sum().sum() #gives overall sum of null values
# Out:
# np.int64(9)

# %%
[feature for feature in df.columns if df[feature].isnull().sum()>0] #gives column which has null values
# Out:
# ['Cuisines']

# %%
x=df.isnull()
sns.heatmap(x,yticklabels=False,cbar=True,cmap='viridis')
plt.show()

# %%
# Example data for demonstrating heatmap
#data = np.random.rand(5,5)  # 10x10 matrix of random numbers
#print(data)
# Heatmap with color bar
#sns.heatmap(data,yticklabels=True, cbar=True, cmap='viridis')
#plt.show()
# Out:
# [[0.74987493 0.08829853 0.03114453 0.93749388 0.48611658]
#  [0.22775424 0.75983921 0.90979935 0.99745912 0.90348302]
#  [0.26694999 0.10616352 0.20700721 0.6411848  0.57344143]
#  [0.74762614 0.41895979 0.34759835 0.72582663 0.45188844]
#  [0.02475258 0.40536205 0.7567681  0.84030971 0.34728735]]

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df_country=pd.read_excel(r"C:\Users\Garima Rawat\OneDrive\Datasets\EDA-Zomato\Country-Code.xlsx")
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
#!pip install openpyxl #used when pandas dealing with excel files

# %%
df_country.shape
# Out:
# (15, 2)

# %%
df_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  15 non-null     int64
#  1   Country       15 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 372.0+ bytes

# %%
final_df = pd.merge(df, df_country, on = 'Country Code', how = 'left') #uses left join

# %%
final_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
Temp = pd.DataFrame(final_df.Country.value_counts())
Temp
# Out:
#                 count
# Country
# India            8652
# United States     434
# United Kingdom     80
# Brazil             60
# South Africa       60
# UAE                60
# New Zealand        40
# Turkey             34
# Australia          24
# Phillipines        22
# Indonesia          21
# Qatar              20
# Singapore          20
# Sri Lanka          20
# Canada              4

# %%
Temp.index
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'South Africa',
#        'UAE', 'New Zealand', 'Turkey', 'Australia', 'Phillipines', 'Indonesia',
#        'Qatar', 'Singapore', 'Sri Lanka', 'Canada'],
#       dtype='object', name='Country')

# %%
plt.pie(Temp['count'][:3], labels = Temp.index[:3], autopct='%1.1f%%')
plt.show()

# %%
country_names = final_df.Country.value_counts().index

# %%
country_names
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'South Africa',
#        'UAE', 'New Zealand', 'Turkey', 'Australia', 'Phillipines', 'Indonesia',
#        'Qatar', 'Singapore', 'Sri Lanka', 'Canada'],
#       dtype='object', name='Country')

# %%
country_val = final_df.Country.value_counts().values
country_val
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4])

# %%
plt.pie(country_val, labels=country_names)
plt.show()

# %%
plt.pie(country_val[:3], labels=country_names[:3], autopct='%1.2f%%')
plt.show()

# %% [raw]
# Observation: This indicates that maximum number of transactions for zomato are from india

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size()
# Out:
# Aggregate rating  Rating color  Rating text
# 0.0               White         Not rated      2148
# 1.8               Red           Poor              1
# 1.9               Red           Poor              2
# 2.0               Red           Poor              7
# 2.1               Red           Poor             15
# 2.2               Red           Poor             27
# 2.3               Red           Poor             47
# 2.4               Red           Poor             87
# 2.5               Orange        Average         110
# 2.6               Orange        Average         191
# 2.7               Orange        Average         250
# 2.8               Orange        Average         315
# 2.9               Orange        Average         381
# 3.0               Orange        Average         468
# 3.1               Orange        Average         519
# 3.2               Orange        Average         522
# 3.3               Orange        Average         483
# ...

# %%
final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index() #converts group data into dataframe
# Out:
#     Aggregate rating Rating color Rating text     0
# 0                0.0        White   Not rated  2148
# 1                1.8          Red        Poor     1
# 2                1.9          Red        Poor     2
# 3                2.0          Red        Poor     7
# 4                2.1          Red        Poor    15
# 5                2.2          Red        Poor    27
# 6                2.3          Red        Poor    47
# 7                2.4          Red        Poor    87
# 8                2.5       Orange     Average   110
# 9                2.6       Orange     Average   191
# 10               2.7       Orange     Average   250
# 11               2.8       Orange     Average   315
# 12               2.9       Orange     Average   381
# 13               3.0       Orange     Average   468
# 14               3.1       Orange     Average   519
# 15               3.2       Orange     Average   522
# 16               3.3       Orange     Average   483
# ...

# %%
ratings = final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns = {0:'Rating Count'})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [raw]
# Conclusions or Observations
# When rating is between 4.5 to 4.9 ---> Excellent
# When rating is between 4.0 to 3.4 ---> Very Good
# When rating is between 3.5 to 3.9 ---> Good
# When rating is between 3.0 to 3.4 ---> Average
# When rating is between 2.5 to 2.9 ---> Average
# When rating is between 2.0 to 2.4 ---> Poor

# %%
ratings.head(10)
# Out:
#    Aggregate rating Rating color Rating text  Rating Count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15
# 5               2.2          Red        Poor            27
# 6               2.3          Red        Poor            47
# 7               2.4          Red        Poor            87
# 8               2.5       Orange     Average           110
# 9               2.6       Orange     Average           191

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (12,8) #rcParams set the size of graph in inches
sns.barplot(x = 'Aggregate rating', y = 'Rating Count', data = ratings)
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %%
plt.figure(figsize = (12, 8))
sns.barplot(x = 'Aggregate rating', y = 'Rating Count', data = ratings)
plt.show()

# %%
matplotlib.rcParams['figure.figsize']=(12,8)
sns.barplot(x='Aggregate rating', y='Rating Count', hue='Rating color', data=ratings)
plt.legend()
plt.show()

# %%
sns.barplot(x='Aggregate rating', y='Rating Count',hue='Rating color', data=ratings, palette=['blue', 'red', 'orange', 'yellow', 'green', 'darkgreen'])
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='Rating Count'>

# %% [raw]
# Observation: Not rated count is very high
# Maximum number of ratings are between 2.5 and 3.4

# %%
sns.countplot(x='Rating color', data = ratings, palette = ['blue', 'red', 'orange', 'yellow', 'green', 'darkgreen']) #countplot
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %%
#Find the countries name that has zero ratings
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
final_df[final_df['Rating color']=='White'].groupby('Country').size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %%
final_df.groupby(['Aggregate rating', 'Country']).size().reset_index().head(20)
# Out:
#     Aggregate rating         Country     0
# 0                0.0          Brazil     5
# 1                0.0           India  2139
# 2                0.0  United Kingdom     1
# 3                0.0   United States     3
# 4                1.8           India     1
# 5                1.9           India     2
# 6                2.0           India     7
# 7                2.1           India    15
# 8                2.2           India    26
# 9                2.2   United States     1
# 10               2.3           India    46
# 11               2.3     New Zealand     1
# 12               2.4       Australia     1
# 13               2.4           India    83
# 14               2.4       Sri Lanka     1
# 15               2.4             UAE     1
# 16               2.4   United States     1
# 17               2.5           India   109
# 18               2.5       Sri Lanka     1
# 19               2.6       Australia     1

# %% [raw]
# Observation: Maximum number of zero ratings are from Indian Customers

# %%
#Find out which currency is used by which Country
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.groupby(['Currency','Country']).size().reset_index()
# Out:
#                   Currency         Country     0
# 0         Botswana Pula(P)     Phillipines    22
# 1       Brazilian Real(R$)          Brazil    60
# 2                Dollar($)       Australia    24
# 3                Dollar($)          Canada     4
# 4                Dollar($)       Singapore    20
# 5                Dollar($)   United States   434
# 6       Emirati Diram(AED)             UAE    60
# 7       Indian Rupees(Rs.)           India  8652
# 8   Indonesian Rupiah(IDR)       Indonesia    21
# 9            NewZealand($)     New Zealand    40
# 10              Pounds(£)  United Kingdom    80
# 11         Qatari Rial(QR)           Qatar    20
# 12                 Rand(R)    South Africa    60
# 13   Sri Lankan Rupee(LKR)       Sri Lanka    20
# 14        Turkish Lira(TL)          Turkey    34

# %%
#Which Countries do have online delivery options
online=final_df.groupby(['Has Online delivery','Country']).size().reset_index(name='count')
online.head()
# Out:
#   Has Online delivery    Country  count
# 0                  No  Australia     24
# 1                  No     Brazil     60
# 2                  No     Canada      4
# 3                  No      India   6229
# 4                  No  Indonesia     21

# %%
final_df[final_df['Has Online delivery'] == 'Yes'].Country.value_counts()
# Out:
# Country
# India    2423
# UAE        28
# Name: count, dtype: int64

# %% [raw]
# Observation: Online deliveries are available in UAE and India

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Country', y='count', hue='Has Online delivery', data=online)
plt.title("Online Delivery Availability by Country")
plt.show()

# %%
#Create a Pie Chart Distribution for top 5 Cities Distribution
City_names = final_df.City.value_counts().values
City_labels = final_df.City.value_counts().index
plt.pie(City_names[:5], labels = City_labels[:5], autopct = '%1.2f%%')
plt.show()

# %%
City_labels
# Out:
# Index(['New Delhi', 'Gurgaon', 'Noida', 'Faridabad', 'Ghaziabad',
#        'Bhubaneshwar', 'Lucknow', 'Ahmedabad', 'Amritsar', 'Guwahati',
#        ...
#        'Forrest', 'East Ballina', 'Huskisson', 'Inverloch', 'Lakeview',
#        'Lakes Entrance', 'Mohali', 'Panchkula', 'Bandung', 'Randburg'],
#       dtype='object', name='City', length=141)

# %%
#Top 10 cuisines
final_df.groupby((['Cuisines'])).size().reset_index().head(10)
# Out:
#                                     Cuisines   0
# 0                                    Afghani   4
# 1                  Afghani, Mughlai, Chinese   1
# 2                      Afghani, North Indian   1
# 3  Afghani, North Indian, Pakistani, Arabian   1
# 4                                    African   1
# 5                        African, Portuguese   1
# 6                                   American  31
# 7                    American, Asian, Burger   1
# 8         American, Asian, European, Seafood   1
# 9          American, Asian, Italian, Seafood   1

# %%
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
final_df.drop('Locality Verbose', axis = 1, inplace = True) #inplace refers to modification to be done in existing data frame, axis means column needs to be deleted

# %%
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality   Longitude   Latitude  \
# 0   Century City Mall, Poblacion, Makati City  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City  121.014101  14.553708
#
#                      Cuisines  Average Cost for two  ... Has Table booking  \
# 0  French, Japanese, Desserts                  1100  ...               Yes
# 1                    Japanese                  1200  ...               Yes
#
#   Has Online delivery Is delivering now Switch to order menu Price range  \
# 0                  No                No                   No           3
# ...

# %%
# Top 5 Restaurants in Each Country w.r.t to Votes

barplot = final_df.groupby('Country', as_index = False)[['Restaurant Name', 'Votes']].max().sort_values(by = 'Votes', ascending = False).set_index('Restaurant Name').head(10)
barplot.head(5)
# Out:
#                              Country  Votes
# Restaurant Name
# {Niche} - Cafe & Bar           India  10934
# Zunzi's                United States   3157
# Zaroob                           UAE   2510
# Zenbu                      Indonesia   2212
# sketch Gallery        United Kingdom   1326

# %%
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
plt.figure(figsize = (10,6))
plt.bar(barplot['Country'], barplot['Votes'], color = colors)
plt.xticks(rotation = 90) #rotation of x axis text
plt.show()

# %%
#Top 5 Restaurants in each Country
def plot(final_df, Country):
    final_df = final_df[final_df['Country'] == Country][['Restaurant Name', 'Rating text', 'Votes']].sort_values(by = 'Votes', ascending = False).head(5)
    plt.bar(final_df['Restaurant Name'], final_df['Votes'])
    plt.xticks(rotation = 30)
    plt.title("Top Five Restaurants of {}".format(Country))
    plt.show()

# %%
plot(final_df,'India')

# %%
plot(final_df, 'UAE')

# %%
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
# Country with Online Delivery
def plot(final_df, Country):
    final_df = final_df[final_df['Country'] == Country]['Has Online delivery'].value_counts()
    plt.pie(final_df, autopct = '%1.1f%%', colors = ['red', 'blue'],  labels = ['No', 'Yes'])
    plt.xticks(rotation = 30)
    plt.title("Countries having Online Deliveries {}".format(Country))
    plt.show()

# %%
final_df[final_df['Has Online delivery'] == 'Yes'].Country.value_counts()
# Out:
# Country
# India    2423
# UAE        28
# Name: count, dtype: int64

# %%
plot(final_df, 'India')

# %%
plot(final_df, 'UAE')

# %%
# Country with Table Bookings option
def plot(final_df, Country):
    final_df = final_df[final_df['Country'] == Country]['Has Table booking'].value_counts()
    plt.pie(final_df, autopct = '%1.1f%%', colors = ['red', 'blue'],  labels = ['No', 'Yes'])
    plt.xticks(rotation = 30)
    plt.title("Countries having Table Booking Status {}".format(Country)) #format replaces {} with country name
    plt.show()

# %%
plot(final_df, 'India')

# %%
plot(final_df, 'United Kingdom')

# %%
def plot(final_df, Country):
    x = final_df[final_df['Country'] == Country]['Rating text'].value_counts(normalize = True)
    plt.pie(x, autopct = '%1.1f%%', colors = ['orange','grey', 'blue', 'yellow', 'green', 'darkgreen'],  labels = final_df[final_df['Country'] == Country]['Rating text'].value_counts(normalize = True).index)
    plt.title(f"Restaurant Rating Percentage of {Country}")
    plt.show()

# %%
final_df[final_df['Country'] == 'India']['Rating text'].value_counts(normalize = True).index #normalize converts these counts into percentages (relative frequencies).
# Out:
# Index(['Average', 'Not rated', 'Good', 'Very Good', 'Poor', 'Excellent'], dtype='object', name='Rating text')

# %%
plot(final_df, 'India')

# %%
plot(final_df, 'United States')

# %%
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %%
final_df['Cuisines'].unique()
# Out:
# array(['French, Japanese, Desserts', 'Japanese',
#        'Seafood, Asian, Filipino, Indian', ..., 'Burger, Izgara',
#        'World Cuisine, Patisserie, Cafe', 'Italian, World Cuisine'],
#       shape=(1826,), dtype=object)

# %%
plt.hist(final_df['Aggregate rating'], bins = 10) #Divides the range of ratings into 10 equal intervals (bins).

plt.show()

# %%
final_df.groupby('Rating text')['Aggregate rating'].count().plot(kind = 'pie', autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='Aggregate rating'>

# %%
final_df['Expensive'] = '' #creates new column with blank values

# %%
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Online delivery Is delivering now  \
# 0  French, Japanese, Desserts  ...                   No                No
# 1                    Japanese  ...                   No                No
#
# ...

# %%
for i, j in enumerate (final_df['Price range']):
    if j == 4:
        final_df['Expensive'][i] = 'Highly Expensive'
    elif j == 3:
        final_df['Expensive'][i] = 'Expensive'
    elif j == 2:
        final_df['Expensive'][i] = 'Moderate'
    elif j == 1:
        final_df['Expensive'][i] = 'Cheap'

# %%
final_df['Expensive'].unique()
# Out:
# array(['Expensive', 'Highly Expensive', 'Moderate', 'Cheap'], dtype=object)

# %%
final_df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
final_df['Expensive'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
final_df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Online delivery Is delivering now  \
# 0  French, Japanese, Desserts  ...                   No                No
# 1                    Japanese  ...                   No                No
#
# ...

# %%
final_df.to_excel(r"C:\Users\Garima Rawat\OneDrive\Datasets\EDA-Zomato\Zomato_final_data.xlsx", index = False)
